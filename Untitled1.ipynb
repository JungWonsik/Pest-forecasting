# %%
print('hello,python')
# Out:
# hello,python

# %%
a=1
b=2
a+b, a*b
# Out:
# (3, 2)

# %%
print('잠오는 날')
# Out:
# 잠오는 날

# %%
print('조아요''\n수요일')
# Out:
# 조아요
# 수요일

# %%
print('hello, python')
# Out:
# hello, python

# %%
a+b
# Out:
# 3

# %%
a*b
# Out:
# 2

# %%
a=5
if a >1 :
    print('True')
# Out:
# True

# %%
a=5
if a >1 :
    print('True')
# Out:
# True

# %%
import sys, os
import math as A
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-33-0f1c7910518b> in <module>
#       1 import sys, os
#       2 import math as A
# ----> 3 import numpy as np
#
# ModuleNotFoundError: No module named 'numpy'

# %%
#p22 파이썬 라이브러리

'''
sys : 파이썬 인터프리터가 제공하는 변수와 함수를 직접 제어할 수 있게 해주는 라이브러리
OS : 환경 변수나 디렉터리, 파일 등의 OS자원을 제어할 수 있게 해주는 라이브러리
math : 수학과 관련된 문제를 해결 할 수 있는 라이브러리
numpy : 과학 연산 위한 라이브러리, 리스트, 배열, 매트릭스 지원
SciPy : 과학용 일반함수 목록제공
Matplotlib : 데이터 시각화 라이브러리
pandas : 고수준 데이터 프레임 
'''
# Out:
# '\nsys : 파이썬 인터프리터가 제공하는 변수와 함수를 직접 제어할 수 있게 해주는 라이브러리\nOS : 환경 변수나 디렉터리, 파일 등의 OS자원을 제어할 수 있게 해주는 라이브러리\nmath : 수학과 관련된 문제를 해결 할 수 있는 라이브러리\nnumpy : 과학 연산 위한 라이브러리, 리스트, 배열, 매트릭스 지원\nSciPy : 과학용 일반함수 목록제공\nMatplotlib : 데이터 시각화 라이브러리\npandas : 고수준 데이터 프레임 \n'

# %%
import pandas as pd
data = pd.read_csv('C:/Users/user/Desktop/bug_weather_2018.csv',encoding='ms949')
data1 = pd.read_csv('C:/Users/user/Desktop/bug_weather_2017',encoding='ms949')
data2 = pd.read_csv('C:/Users/user/Desktop/bug_weather_2016',encoding='ms949')
data3 = pd.read_csv('C:/Users/user/Desktop/bug_weather_2015',encoding='ms949')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-81a0e0fa31ca> in <module>
#       1 import pandas as pd
# ----> 2 data = pd.read_csv('C:/Users/user/Desktop/bug_weather_2018',encoding='ms949')
#       3 data1 = pd.read_csv('C:/Users/user/Desktop/bug_weather_2017',encoding='ms949')
#       4 data2 = pd.read_csv('C:/Users/user/Desktop/bug_weather_2016',encoding='ms949')
#       5 data3 = pd.read_csv('C:/Users/user/Desktop/bug_weather_2015',encoding='ms949')
#
# ...

# %%
import pandas as pd
data = pd.read_csv('C:/Users/user/Desktop/bug_weather_2018.csv',encoding='ms949')
data1 = pd.read_csv('C:/Users/user/Desktop/bug_weather_2017.csv',encoding='ms949')
data2 = pd.read_csv('C:/Users/user/Desktop/bug_weather_2016.csv',encoding='ms949')
data3 = pd.read_csv('C:/Users/user/Desktop/bug_weather_2015.csv',encoding='ms949')

# %%
data4 = data.append(data1)
data4 = data4.append(data2)
data4 = data4.append(data3)
data=data4

# %%
data=data4

# %%
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='함평군'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='영광군')][data.columns[j]])[0]
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='나주시'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='장흥군')][data.columns[j]])[0]
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='신안군'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='해남군')][data.columns[j]])[0]
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='무안군'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='해남군')][data.columns[j]])[0]                
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='담양군'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='순천시')][data.columns[j]])[0]
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='곡성군'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='순천시')][data.columns[j]])[0]
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='화순군'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='보성군')][data.columns[j]])[0]
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='구례군'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='광양시')][data.columns[j]])[0]
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='영암군'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='강진군')][data.columns[j]])[0]
for j in range(25,40):
    for i in set(data['입력기준일자']):
        data.loc[(data['입력기준일자']==i) & (data['시군구명']=='장성군'),::j]= \
        list(data[(data['입력기준일자']==i) & (data['시군구명']=='영광군')][data.columns[j]])[0]

# %%
data4 = data[['입력기준일자','시군구명','일강수량(mm)']]

# %%
data5 = pd.read_csv('C:/Users/user/Desktop/finall_2.csv',encoding='ms949')

# %%
data6 = pd.merge(data5,data4,on=['입력기준일자','시군구명'])

# %%
data6.to_csv('C:/Users/user/Desktop/finall_view.csv',encoding='ms949')

# %%
len(data6)
# Out:
# 64260

# %%
len(data5)
# Out:
# 64260

# %%
len(data4)
# Out:
# 671

# %%
data4=data4.groupby(['입력기준일자','시군구명']).sum()
